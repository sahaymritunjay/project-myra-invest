-- %%
SELECT
technicalSignal,
COUNT(*) AS totalStocks
FROM workspace.myra_invest.gold_stock_signals
GROUP BY technicalSignal;

SELECT
symbol,
dailyReturnPct
FROM workspace.myra_invest.gold_stock_signals
ORDER BY dailyReturnPct DESC
LIMIT 10;

SELECT
symbol,
volatility5
FROM workspace.myra_invest.gold_stock_signals
ORDER BY volatility5 DESC
LIMIT 10;
