# %%
dbutils.fs.mkdirs("dbfs:/FileStore/project_myra/bronze")
dbutils.fs.mkdirs("dbfs:/FileStore/project_myra/silver")
dbutils.fs.mkdirs("dbfs:/FileStore/project_myra/gold")
dbutils.fs.mkdirs("dbfs:/FileStore/project_myra/news")
