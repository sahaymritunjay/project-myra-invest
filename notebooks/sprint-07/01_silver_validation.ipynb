-- %%
SELECT
symbol,
priceChange,
priceChangePct
FROM myra_invest.silver_stock_prices
ORDER BY priceChangePct DESC;

SELECT COUNT(*) FROM myra_invest.silver_stock_prices;

SELECT DISTINCT tradeDate
FROM myra_invest.silver_stock_prices;
